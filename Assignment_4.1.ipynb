# %%
# prompt: While Loop

# initialize a counter
counter = 0

# set the loop condition
while counter < 5:
  print(f"Counter value: {counter}")
  # increment the counter
  counter += 1

print("Loop finished!")
# Out:
# The counter is: 0
# The counter is: 1
# The counter is: 2
# The counter is: 3
# The counter is: 4
# Loop finished!
