# %%
# Assignment 5.1

num1 = int(input("Enter first Number: "))
num2 = int(input("Enter second Number: "))
num3 = int(input("Enter third Number: "))
print("The max among these three is: ", max(num1, num2, num3))

# Enter first Number: 2
# Enter second Number: 8
# Enter third Number: 1
# The max among these three is:  8

# Assignment 5.2

num = int(input("Enter a number: "))
sum = 0
for i in range(1, num+1):
  if (i % 7 == 0 and i % 9 == 0):
    sum += i
print("The sum of numbers divisible by 7 & 9 from 1 to", num ," is: ", sum)

# Assignment 5.3

numm = int(input("Enter a number: "))
summ = 0

for i in range(1, numm+1):
  for j in range(2, int(i/2) +1):
    if( i % j == 0):
      break
  else:
    summ += i
print("The sum of prime numbers from 1 to " , numm , " is: ",summ)

# Enter a number: 5
# The sum of prime numbers from 1 to  5  is:  11
